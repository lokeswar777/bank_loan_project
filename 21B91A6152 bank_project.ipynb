# %% [markdown]
# #mounting google drive in colab

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd drive/MyDrive/btech/internship/el project
# Out:
# /content/drive/MyDrive/btech/internship/el project

# %% [markdown]
# #Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Ignore harmless warnings

import warnings
warnings.filterwarnings("ignore")

# Set to display all the columns in dataset

pd.set_option("display.max_columns", None)

# %% [markdown]
# #reading dataset

# %%
pdata=pd.read_csv("bank-direct-marketing-campaigns.csv")
pdata.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no

# %% [markdown]
# #back up file

# %%
pdatabk=pdata.copy()

# %% [markdown]
# #Data Mining 01

# %%
pdata.shape
# Out:
# (41188, 20)

# %%
pdata.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
pdata['y'].value_counts()
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %%
pdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  campaign        41188 non-null  int64
#  11  pdays           41188 non-null  int64
#  12  previous        41188 non-null  int64
#  13  poutcome        41188 non-null  object
#  14  emp.var.rate    41188 non-null  float64
#  15  cons.price.idx  41188 non-null  float64
#  16  cons.conf.idx   41188 non-null  float64
#  17  euribor3m       41188 non-null  float64
#  18  nr.employed     41188 non-null  float64
#  19  y               41188 non-null  object
# dtypes: float64(5), int64(4), object(11)
# memory usage: 6.3+ MB

# %%
pdata.duplicated().any()
# Out:
# True

# %% [markdown]
# ##Dropping Duplicates

# %%
pdata=pdata.drop_duplicates()
pdata
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  campaign  pdays  previous     poutcome  \
# 0      telephone   may         mon         1    999         0  nonexistent
# 1      telephone   may         mon         1    999         0  nonexistent
# 2      telephone   may         mon         1    999         0  nonexistent
# 3      telephone   may         mon         1    999         0  nonexistent
# 4      telephone   may         mon         1    999         0  nonexistent
# ...          ...   ...         ...       ...    ...       ...          ...
# 41183   cellular   nov         fri         1    999         0  nonexistent
# 41184   cellular   nov         fri         1    999         0  nonexistent
# 41185   cellular   nov         fri         2    999         0  nonexistent
# 41186   cellular   nov         fri         1    999         0  nonexistent
# 41187   cellular   nov         fri         3    999         1      failure
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# 0               1.1          93.994          -36.4      4.857       5191.0
# 1               1.1          93.994          -36.4      4.857       5191.0
# 2               1.1          93.994          -36.4      4.857       5191.0
# 3               1.1          93.994          -36.4      4.857       5191.0
# 4               1.1          93.994          -36.4      4.857       5191.0
# ...             ...             ...            ...        ...          ...
# 41183          -1.1          94.767          -50.8      1.028       4963.6
# 41184          -1.1          94.767          -50.8      1.028       4963.6
# 41185          -1.1          94.767          -50.8      1.028       4963.6
# 41186          -1.1          94.767          -50.8      1.028       4963.6
# 41187          -1.1          94.767          -50.8      1.028       4963.6
#
#          y
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
# ...    ...
# 41183  yes
# 41184   no
# 41185   no
# 41186  yes
# 41187   no
#
# [39404 rows x 20 columns]

# %%
pdata=pdata.reset_index(drop=True)
pdata=pdata.copy()

# %%
pdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39404 entries, 0 to 39403
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             39404 non-null  int64
#  1   job             39404 non-null  object
#  2   marital         39404 non-null  object
#  3   education       39404 non-null  object
#  4   default         39404 non-null  object
#  5   housing         39404 non-null  object
#  6   loan            39404 non-null  object
#  7   contact         39404 non-null  object
#  8   month           39404 non-null  object
#  9   day_of_week     39404 non-null  object
#  10  campaign        39404 non-null  int64
#  11  pdays           39404 non-null  int64
#  12  previous        39404 non-null  int64
#  13  poutcome        39404 non-null  object
#  14  emp.var.rate    39404 non-null  float64
#  15  cons.price.idx  39404 non-null  float64
#  16  cons.conf.idx   39404 non-null  float64
#  17  euribor3m       39404 non-null  float64
#  18  nr.employed     39404 non-null  float64
#  19  y               39404 non-null  object
# dtypes: float64(5), int64(4), object(11)
# memory usage: 6.0+ MB

# %% [markdown]
# ##Renaming features (attributes)

# %%
pdata=pdata.rename(columns={'emp.var.rate':'emp_var_rate'},inplace=False)
pdata=pdata.rename(columns={'cons.price.idx':'cons_price_idx'},inplace=False)
pdata=pdata.rename(columns={'cons.conf.idx':'cons.conf.idx'},inplace=False)
pdata=pdata.rename(columns={'cons.conf.idx':'cons_conf_idx'},inplace=False)
pdata=pdata.rename(columns={'nr.employed':'nr_employed'},inplace=False)

# %%
pdata.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp_var_rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons_price_idx  cons_conf_idx  euribor3m  nr_employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no

# %% [markdown]
# #Data Mining 02

# %%
from sklearn.preprocessing import LabelEncoder
def label_transform(x):
    le = LabelEncoder()
    Encoded_le = le.fit_transform(x)
    return Encoded_le

# %%
catagoral_label=['job','marital','education','default','housing','loan','month','day_of_week','poutcome','contact','y']

# %%
for x in catagoral_label:
    pdata[x] = label_transform(pdata[x])

# %%
pdata.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        1          0        0        0     0        1      6
# 1   57    7        1          3        1        0     0        1      6
# 2   37    7        1          3        0        2     0        1      6
# 3   40    0        1          1        0        0     0        1      6
# 4   56    7        1          3        0        0     2        1      6
#
#    day_of_week  campaign  pdays  previous  poutcome  emp_var_rate  \
# 0            1         1    999         0         1           1.1
# 1            1         1    999         0         1           1.1
# 2            1         1    999         0         1           1.1
# 3            1         1    999         0         1           1.1
# 4            1         1    999         0         1           1.1
#
#    cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# 0          93.994          -36.4      4.857       5191.0  0
# 1          93.994          -36.4      4.857       5191.0  0
# 2          93.994          -36.4      4.857       5191.0  0
# 3          93.994          -36.4      4.857       5191.0  0
# 4          93.994          -36.4      4.857       5191.0  0

# %%
pdata['y'].value_counts()
# Out:
# 0    34806
# 1     4598
# Name: y, dtype: int64

# %%
p=np.array([pdata['y'].value_counts()[1],pdata['y'].value_counts()[0]])

# %%
p
# Out:
# array([ 4598, 34806])

# %% [markdown]
# #Data Visualization

# %%
import matplotlib.pyplot as plt

#plt.plot(pdata['y'].value_counts()[1],pdata['y'].value_counts()[0])
plt.pie(p,labels=['no','yes'])
plt.title("proportion of target variable values")

plt.show()

# %%
plt.hist(pdata['default'])
plt.title('default')
# Out:
# Text(0.5, 1.0, 'default')

# %%
plt.hist(pdata['age'])
plt.title('age')
# Out:
# Text(0.5, 1.0, 'age')

# %%
plt.hist(pdata['job'])
plt.title("job")
# Out:
# Text(0.5, 1.0, 'job')

# %%
plt.hist(pdata['marital'])
plt.title("marital")
# Out:
# Text(0.5, 1.0, 'marital')

# %%
plt.hist(pdata['education'])
plt.title('education')
# Out:
# Text(0.5, 1.0, 'education')

# %%
plt.hist(pdata['housing'])
plt.title('housing')
# Out:
# Text(0.5, 1.0, 'housing')

# %%
plt.hist(pdata['loan'])
plt.title('loan')
# Out:
# Text(0.5, 1.0, 'loan')

# %%
plt.hist(pdata['contact'])
plt.title('contact')
# Out:
# Text(0.5, 1.0, 'contact')

# %%
plt.hist(pdata['month'])
plt.title('month')
# Out:
# Text(0.5, 1.0, 'month')

# %% [markdown]
# ##Heat map

# %%
import seaborn as sns
tc = pdata.corr()
sns.heatmap(tc)
plt.show()

# %%
pdata['y'].value_counts()
# Out:
# 0    34806
# 1     4598
# Name: y, dtype: int64

# %% [markdown]
# ##choosing features columns

# %%
cols=['age','campaign','pdays','previous','emp_var_rate','cons_price_idx','cons_conf_idx','euribor3m','nr_employed']

# %%
#IDENTIFY INDEPENDENT AND TARGET
indepvar=[]
for col in pdata.columns:
    if col !='y':
        indepvar.append(col)
targetvar='y'
x=pdata[indepvar]
y=pdata[targetvar]

# %%
from  sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((27582, 19), (11822, 19), (27582,), (11822,))

# %%
# Count the target or dependent variable by '0' & '1' and their proportion
# (>= 10 : 1, then the dataset is imbalance data)
#aplicable to clasification models

y_gen_count =pdata.y.value_counts()
print('Class 0:', y_gen_count[0])
print('Class 1:',y_gen_count[1])
print('Proportion:', round(y_gen_count[0] / y_gen_count[1], 2), ': 1')
print('Total loan records:', len(pdata))
# Out:
# Class 0: 34806
# Class 1: 4598
# Proportion: 7.57 : 1
# Total loan records: 39404

# %% [markdown]
# ##Scaling

# %%
# Scaling the features by using MinMaxScaler

from sklearn.preprocessing import MinMaxScaler

mmscaler = MinMaxScaler(feature_range=(0, 1))

x_train[cols] = mmscaler.fit_transform(x_train[cols])
x_train = pd.DataFrame(x_train)

x_test[cols] = mmscaler.fit_transform(x_test[cols])
x_test = pd.DataFrame(x_test)

# %%
knnresults=pd.read_csv(r"knnresults.csv",header=0)
knnresults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, KNN K Value, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %%
#loading the results file for svm
emresults1=pd.read_csv(r"em.csv",header=0)
emresults1.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %% [markdown]
# ##KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import sklearn.metrics as metrics

from sklearn.metrics import roc_curve, roc_auc_score

accuracy = []

for a in range(1, 21, 1):

    k = a

    # Build the model

    ModelKNN = KNeighborsClassifier(n_neighbors=k)

    # Train the model

    ModelKNN.fit(x_train, y_train)

    # Predict the model

    y_pred = ModelKNN.predict(x_test)
    y_pred_prob = ModelKNN.predict_proba(x_test)

    print('KNN_K_value = ', a)

    # Print the model name

    print('Model Name: ', ModelKNN)

    # confusion matrix in sklearn

    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    # actual values

    actual = y_test

    # predicted values

    predicted = y_pred

    # confusion matrix

    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)

    # outcome values order in sklearn

    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)

    # classification report for precision, recall f1-score and accuracy

    C_Report = classification_report(actual,predicted,labels=[1,0])

    print('Classification report : \n', C_Report)

    # calculating the metrics

    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);

    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);

    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1.
    # A model with a score of +1 is a perfect model and -1 is a poor model

    from math import sqrt

    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)

    # Area under ROC curve

    from sklearn.metrics import roc_curve, roc_auc_score

    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

    # ROC Curve

    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, ModelKNN.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    #plt.savefig('Log_ROC')
    plt.show()
    #------------------------------------------------------------------------------
    new_row = {'Model Name' : ModelKNN,
               'KNN K Value' : a,
               'True_Positive' : tp,
               'False_Negative' : fn,
               'False_Positive' : fp,
               'True_Negative' : tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    knnresults = knnresults.append(new_row, ignore_index=True)
# Out:
# KNN_K_value =  1
# Model Name:  KNeighborsClassifier(n_neighbors=1)
# Confusion matrix :
#  [[ 377 1021]
#  [ 949 9475]]
# Outcome values :
#  377 1021 949 9475
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.28      0.27      0.28      1398
#            0       0.90      0.91      0.91     10424
#
#     accuracy                           0.83     11822
#    macro avg       0.59      0.59      0.59     11822
# weighted avg       0.83      0.83      0.83     11822
#
# Accuracy : 83.3 %
# Precision : 28.4 %
# Recall : 27.0 %
# F1 Score : 0.277
# Specificity or True Negative Rate : 90.9 %
# Balanced Accuracy : 59.0 %
# MCC : 0.183
# roc_auc_score: 0.589
# KNN_K_value =  2
# Model Name:  KNeighborsClassifier(n_neighbors=2)
# Confusion matrix :
#  [[  164  1234]
#  [  186 10238]]
# Outcome values :
#  164 1234 186 10238
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.47      0.12      0.19      1398
#            0       0.89      0.98      0.94     10424
#
#     accuracy                           0.88     11822
#    macro avg       0.68      0.55      0.56     11822
# weighted avg       0.84      0.88      0.85     11822
#
# Accuracy : 88.0 %
# Precision : 46.9 %
# Recall : 11.7 %
# F1 Score : 0.188
# Specificity or True Negative Rate : 98.2 %
# Balanced Accuracy : 55.0 %
# MCC : 0.189
# roc_auc_score: 0.55
# KNN_K_value =  3
# Model Name:  KNeighborsClassifier(n_neighbors=3)
# Confusion matrix :
#  [[ 332 1066]
#  [ 431 9993]]
# Outcome values :
#  332 1066 431 9993
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.44      0.24      0.31      1398
#            0       0.90      0.96      0.93     10424
#
#     accuracy                           0.87     11822
#    macro avg       0.67      0.60      0.62     11822
# weighted avg       0.85      0.87      0.86     11822
#
# Accuracy : 87.3 %
# Precision : 43.5 %
# Recall : 23.7 %
# F1 Score : 0.307
# Specificity or True Negative Rate : 95.9 %
# Balanced Accuracy : 59.8 %
# MCC : 0.258
# roc_auc_score: 0.598
# KNN_K_value =  4
# Model Name:  KNeighborsClassifier(n_neighbors=4)
# Confusion matrix :
#  [[  190  1208]
#  [  160 10264]]
# Outcome values :
#  190 1208 160 10264
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.54      0.14      0.22      1398
#            0       0.89      0.98      0.94     10424
#
#     accuracy                           0.88     11822
#    macro avg       0.72      0.56      0.58     11822
# weighted avg       0.85      0.88      0.85     11822
#
# Accuracy : 88.4 %
# Precision : 54.3 %
# Recall : 13.6 %
# F1 Score : 0.217
# Specificity or True Negative Rate : 98.5 %
# Balanced Accuracy : 56.0 %
# MCC : 0.23
# roc_auc_score: 0.56
# KNN_K_value =  5
# Model Name:  KNeighborsClassifier()
# Confusion matrix :
#  [[  288  1110]
#  [  279 10145]]
# Outcome values :
#  288 1110 279 10145
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.51      0.21      0.29      1398
#            0       0.90      0.97      0.94     10424
#
#     accuracy                           0.88     11822
#    macro avg       0.70      0.59      0.61     11822
# weighted avg       0.85      0.88      0.86     11822
#
# Accuracy : 88.3 %
# Precision : 50.8 %
# Recall : 20.6 %
# F1 Score : 0.293
# Specificity or True Negative Rate : 97.3 %
# Balanced Accuracy : 59.0 %
# MCC : 0.271
# roc_auc_score: 0.59
# KNN_K_value =  6
# Model Name:  KNeighborsClassifier(n_neighbors=6)
# Confusion matrix :
#  [[  175  1223]
#  [  145 10279]]
# Outcome values :
#  175 1223 145 10279
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.55      0.13      0.20      1398
#            0       0.89      0.99      0.94     10424
#
#     accuracy                           0.88     11822
#    macro avg       0.72      0.56      0.57     11822
# weighted avg       0.85      0.88      0.85     11822
#
# Accuracy : 88.4 %
# Precision : 54.7 %
# Recall : 12.5 %
# F1 Score : 0.204
# Specificity or True Negative Rate : 98.6 %
# Balanced Accuracy : 55.6 %
# MCC : 0.221
# roc_auc_score: 0.556
# KNN_K_value =  7
# Model Name:  KNeighborsClassifier(n_neighbors=7)
# Confusion matrix :
#  [[  252  1146]
#  [  218 10206]]
# Outcome values :
#  252 1146 218 10206
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.54      0.18      0.27      1398
#            0       0.90      0.98      0.94     10424
#
#     accuracy                           0.88     11822
#    macro avg       0.72      0.58      0.60     11822
# weighted avg       0.86      0.88      0.86     11822
#
# Accuracy : 88.5 %
# Precision : 53.6 %
# Recall : 18.0 %
# F1 Score : 0.27
# Specificity or True Negative Rate : 97.9 %
# Balanced Accuracy : 58.0 %
# MCC : 0.263
# roc_auc_score: 0.58
# KNN_K_value =  8
# Model Name:  KNeighborsClassifier(n_neighbors=8)
# Confusion matrix :
#  [[  162  1236]
#  [  115 10309]]
# Outcome values :
#  162 1236 115 10309
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.58      0.12      0.19      1398
#            0       0.89      0.99      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.74      0.55      0.57     11822
# weighted avg       0.86      0.89      0.85     11822
#
# Accuracy : 88.6 %
# Precision : 58.5 %
# Recall : 11.6 %
# F1 Score : 0.193
# Specificity or True Negative Rate : 98.9 %
# Balanced Accuracy : 55.2 %
# MCC : 0.224
# roc_auc_score: 0.552
# KNN_K_value =  9
# Model Name:  KNeighborsClassifier(n_neighbors=9)
# Confusion matrix :
#  [[  207  1191]
#  [  166 10258]]
# Outcome values :
#  207 1191 166 10258
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.55      0.15      0.23      1398
#            0       0.90      0.98      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.73      0.57      0.59     11822
# weighted avg       0.86      0.89      0.85     11822
#
# Accuracy : 88.5 %
# Precision : 55.5 %
# Recall : 14.8 %
# F1 Score : 0.234
# Specificity or True Negative Rate : 98.4 %
# Balanced Accuracy : 56.6 %
# MCC : 0.244
# roc_auc_score: 0.566
# KNN_K_value =  10
# Model Name:  KNeighborsClassifier(n_neighbors=10)
# Confusion matrix :
#  [[  144  1254]
#  [  101 10323]]
# Outcome values :
#  144 1254 101 10323
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.59      0.10      0.18      1398
#            0       0.89      0.99      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.74      0.55      0.56     11822
# weighted avg       0.86      0.89      0.85     11822
#
# Accuracy : 88.5 %
# Precision : 58.8 %
# Recall : 10.3 %
# F1 Score : 0.175
# Specificity or True Negative Rate : 99.0 %
# Balanced Accuracy : 54.6 %
# MCC : 0.212
# roc_auc_score: 0.547
# KNN_K_value =  11
# Model Name:  KNeighborsClassifier(n_neighbors=11)
# Confusion matrix :
#  [[  184  1214]
#  [  140 10284]]
# Outcome values :
#  184 1214 140 10284
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.57      0.13      0.21      1398
#            0       0.89      0.99      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.73      0.56      0.58     11822
# weighted avg       0.86      0.89      0.85     11822
#
# Accuracy : 88.5 %
# Precision : 56.8 %
# Recall : 13.2 %
# F1 Score : 0.214
# Specificity or True Negative Rate : 98.7 %
# Balanced Accuracy : 56.0 %
# MCC : 0.234
# roc_auc_score: 0.559
# KNN_K_value =  12
# Model Name:  KNeighborsClassifier(n_neighbors=12)
# Confusion matrix :
#  [[  133  1265]
#  [   82 10342]]
# Outcome values :
#  133 1265 82 10342
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.62      0.10      0.16      1398
#            0       0.89      0.99      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.75      0.54      0.55     11822
# weighted avg       0.86      0.89      0.85     11822
#
# Accuracy : 88.6 %
# Precision : 61.9 %
# Recall : 9.5 %
# F1 Score : 0.165
# Specificity or True Negative Rate : 99.2 %
# Balanced Accuracy : 54.4 %
# MCC : 0.211
# roc_auc_score: 0.544
# KNN_K_value =  13
# Model Name:  KNeighborsClassifier(n_neighbors=13)
# Confusion matrix :
#  [[  167  1231]
#  [  115 10309]]
# Outcome values :
#  167 1231 115 10309
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.59      0.12      0.20      1398
#            0       0.89      0.99      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.74      0.55      0.57     11822
# weighted avg       0.86      0.89      0.85     11822
#
# Accuracy : 88.6 %
# Precision : 59.2 %
# Recall : 11.9 %
# F1 Score : 0.199
# Specificity or True Negative Rate : 98.9 %
# Balanced Accuracy : 55.4 %
# MCC : 0.229
# roc_auc_score: 0.554
# KNN_K_value =  14
# Model Name:  KNeighborsClassifier(n_neighbors=14)
# Confusion matrix :
#  [[  124  1274]
#  [   77 10347]]
# Outcome values :
#  124 1274 77 10347
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.62      0.09      0.16      1398
#            0       0.89      0.99      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.75      0.54      0.55     11822
# weighted avg       0.86      0.89      0.85     11822
#
# Accuracy : 88.6 %
# Precision : 61.7 %
# Recall : 8.9 %
# F1 Score : 0.155
# Specificity or True Negative Rate : 99.3 %
# Balanced Accuracy : 54.1 %
# MCC : 0.203
# roc_auc_score: 0.541
# KNN_K_value =  15
# Model Name:  KNeighborsClassifier(n_neighbors=15)
# Confusion matrix :
#  [[  151  1247]
#  [  101 10323]]
# Outcome values :
#  151 1247 101 10323
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.60      0.11      0.18      1398
#            0       0.89      0.99      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.75      0.55      0.56     11822
# weighted avg       0.86      0.89      0.85     11822
#
# Accuracy : 88.6 %
# Precision : 59.9 %
# Recall : 10.8 %
# F1 Score : 0.183
# Specificity or True Negative Rate : 99.0 %
# Balanced Accuracy : 54.9 %
# MCC : 0.22
# roc_auc_score: 0.549
# KNN_K_value =  16
# Model Name:  KNeighborsClassifier(n_neighbors=16)
# Confusion matrix :
#  [[  101  1297]
#  [   63 10361]]
# Outcome values :
#  101 1297 63 10361
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.62      0.07      0.13      1398
#            0       0.89      0.99      0.94     10424
#
#     accuracy                           0.88     11822
#    macro avg       0.75      0.53      0.53     11822
# weighted avg       0.86      0.88      0.84     11822
#
# Accuracy : 88.5 %
# Precision : 61.6 %
# Recall : 7.2 %
# F1 Score : 0.129
# Specificity or True Negative Rate : 99.4 %
# Balanced Accuracy : 53.3 %
# MCC : 0.183
# roc_auc_score: 0.533
# KNN_K_value =  17
# Model Name:  KNeighborsClassifier(n_neighbors=17)
# Confusion matrix :
#  [[  135  1263]
#  [   86 10338]]
# Outcome values :
#  135 1263 86 10338
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.61      0.10      0.17      1398
#            0       0.89      0.99      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.75      0.54      0.55     11822
# weighted avg       0.86      0.89      0.85     11822
#
# Accuracy : 88.6 %
# Precision : 61.1 %
# Recall : 9.7 %
# F1 Score : 0.167
# Specificity or True Negative Rate : 99.2 %
# Balanced Accuracy : 54.4 %
# MCC : 0.211
# roc_auc_score: 0.544
# KNN_K_value =  18
# Model Name:  KNeighborsClassifier(n_neighbors=18)
# Confusion matrix :
#  [[   96  1302]
#  [   52 10372]]
# Outcome values :
#  96 1302 52 10372
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.65      0.07      0.12      1398
#            0       0.89      1.00      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.77      0.53      0.53     11822
# weighted avg       0.86      0.89      0.84     11822
#
# Accuracy : 88.5 %
# Precision : 64.9 %
# Recall : 6.9 %
# F1 Score : 0.124
# Specificity or True Negative Rate : 99.5 %
# Balanced Accuracy : 53.2 %
# MCC : 0.185
# roc_auc_score: 0.532
# KNN_K_value =  19
# Model Name:  KNeighborsClassifier(n_neighbors=19)
# Confusion matrix :
#  [[  123  1275]
#  [   64 10360]]
# Outcome values :
#  123 1275 64 10360
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.66      0.09      0.16      1398
#            0       0.89      0.99      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.77      0.54      0.55     11822
# weighted avg       0.86      0.89      0.85     11822
#
# Accuracy : 88.7 %
# Precision : 65.8 %
# Recall : 8.8 %
# F1 Score : 0.155
# Specificity or True Negative Rate : 99.4 %
# Balanced Accuracy : 54.1 %
# MCC : 0.212
# roc_auc_score: 0.541
# KNN_K_value =  20
# Model Name:  KNeighborsClassifier(n_neighbors=20)
# Confusion matrix :
#  [[   89  1309]
#  [   38 10386]]
# Outcome values :
#  89 1309 38 10386
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.70      0.06      0.12      1398
#            0       0.89      1.00      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.79      0.53      0.53     11822
# weighted avg       0.87      0.89      0.84     11822
#
# Accuracy : 88.6 %
# Precision : 70.1 %
# Recall : 6.4 %
# F1 Score : 0.117
# Specificity or True Negative Rate : 99.6 %
# Balanced Accuracy : 53.0 %
# MCC : 0.188
# roc_auc_score: 0.53

# %% [markdown]
# ##svm poly

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMPoly = SVC(kernel='poly', degree=2, probability=True)

# Train the model

ModelSVMPoly.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMPoly.predict(x_test)
y_pred_prob = ModelSVMPoly.predict_proba(x_test)

# Print the model name

print('Model Name: ', "SVM - Polynominal")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1.
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMPoly.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
print('-----------------------------------------------------------------------------------------------------')
#---
new_row = {'Model Name' : "SVM - Polynominal",
            'True_Positive' : tp,
            'False_Negative' : fn,
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
emresults1 = emresults1.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Polynominal
# Confusion matrix :
#  [[  263  1135]
#  [  129 10295]]
# Outcome values :
#  263 1135 129 10295
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.67      0.19      0.29      1398
#            0       0.90      0.99      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.79      0.59      0.62     11822
# weighted avg       0.87      0.89      0.87     11822
#
# Accuracy : 89.3 %
# Precision : 67.1 %
# Recall : 18.8 %
# F1 Score : 0.294
# Specificity or True Negative Rate : 98.8 %
# Balanced Accuracy : 58.8 %
# MCC : 0.317
# roc_auc_score: 0.588
# -----------------------------------------------------------------------------------------------------

# %% [markdown]
# ##svm linear

# %%
# Training the SVM algorithm with train dataset

from sklearn.svm import SVC

ModelSVM1 = SVC(C=1.0, kernel='linear', degree=3,probability=True)

# Train the model with train data

ModelSVM1 = ModelSVM1.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVM1.predict(x_test)
y_pred_prob = ModelSVM1.predict_proba(x_test)

# Print the model name

print('Model Name: ', "SVM - Linear")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1.
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
model_roc_auc = roc_auc_score(actual, predicted)
fpr, tpr, thresholds = roc_curve(actual,ModelSVM1.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
print('-----------------------------------------------------------------------------------------------------')
#---
new_row = {'Model Name' : "SVM - Linear",
            'True_Positive' : tp,
            'False_Negative' : fn,
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
emresults1 = emresults1.append(new_row, ignore_index=True)
#-------------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Linear
# Confusion matrix :
#  [[  281  1117]
#  [  160 10264]]
# Outcome values :
#  281 1117 160 10264
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.64      0.20      0.31      1398
#            0       0.90      0.98      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.77      0.59      0.62     11822
# weighted avg       0.87      0.89      0.87     11822
#
# Accuracy : 89.2 %
# Precision : 63.7 %
# Recall : 20.1 %
# F1 Score : 0.306
# Specificity or True Negative Rate : 98.5 %
# Balanced Accuracy : 59.3 %
# MCC : 0.316
# roc_auc_score: 0.593
# -----------------------------------------------------------------------------------------------------

# %% [markdown]
# #svm Gaussian

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMGaussian = SVC(kernel='rbf', random_state = 42, class_weight='balanced', probability=True)

# Train the model

ModelSVMGaussian.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMGaussian.predict(x_test)
y_pred_prob = ModelSVMGaussian.predict_proba(x_test)

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Print the model name

print('Model Name: ', "SVM - Gaussian")

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1.
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMGaussian.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
print('-----------------------------------------------------------------------------------------------------')
#---
new_row = {'Model Name' : "SVM - Gaussian",
            'True_Positive' : tp,
            'False_Negative' : fn,
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
emresults1 = emresults1.append(new_row, ignore_index=True)
#---------------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Gaussian
# Confusion matrix :
#  [[ 905  493]
#  [2067 8357]]
# Outcome values :
#  905 493 2067 8357
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.30      0.65      0.41      1398
#            0       0.94      0.80      0.87     10424
#
#     accuracy                           0.78     11822
#    macro avg       0.62      0.72      0.64     11822
# weighted avg       0.87      0.78      0.81     11822
#
# Accuracy : 78.3 %
# Precision : 30.5 %
# Recall : 64.7 %
# F1 Score : 0.414
# Specificity or True Negative Rate : 80.2 %
# Balanced Accuracy : 72.4 %
# MCC : 0.334
# roc_auc_score: 0.725
# -----------------------------------------------------------------------------------------------------

# %% [markdown]
# #svm Sigmoid

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMSig = SVC(kernel='sigmoid', random_state = 42, class_weight='balanced', probability=True)

# Train the model

ModelSVMSig.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMSig.predict(x_test)
y_pred_prob = ModelSVMSig.predict_proba(x_test)

# Print the model name

print('Model Name: ', "SVM - Sigmoid")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1.
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMSig.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
print('-----------------------------------------------------------------------------------------------------')
#---
new_row = {'Model Name' : "SVM - Sigmoid",
            'True_Positive' : tp,
            'False_Negative' : fn,
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
emresults1 = emresults1.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Sigmoid
# Confusion matrix :
#  [[ 713  685]
#  [4865 5559]]
# Outcome values :
#  713 685 4865 5559
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.13      0.51      0.20      1398
#            0       0.89      0.53      0.67     10424
#
#     accuracy                           0.53     11822
#    macro avg       0.51      0.52      0.44     11822
# weighted avg       0.80      0.53      0.61     11822
#
# Accuracy : 53.1 %
# Precision : 12.8 %
# Recall : 51.0 %
# F1 Score : 0.204
# Specificity or True Negative Rate : 53.3 %
# Balanced Accuracy : 52.2 %
# MCC : 0.028
# roc_auc_score: 0.522
# -----------------------------------------------------------------------------------------------------

# %%
##comparision

# %% [markdown]
# ##comprision

# %%
#loading the results file for svm
emresults=pd.read_csv(r"em.csv",header=0)
emresults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# Create objects of classification algorithms with default hyper-parameters

ModelLR = LogisticRegression()
ModelDC = DecisionTreeClassifier()
ModelRF = RandomForestClassifier()
ModelET = ExtraTreesClassifier()
ModelKNN = KNeighborsClassifier(n_neighbors=19)
ModelGNB = GaussianNB()
ModelSVM = SVC(probability=True,kernel='poly')

# Evalution matrix for all the algorithms

#MM = [ModelLR, ModelDC, ModelRF, ModelET, ModelKNN, ModelGNB, ModelSVM]
MM = [ModelLR, ModelDC, ModelRF, ModelET,ModelKNN,ModelGNB,ModelSVM]
for models in MM:

    # Train the model training dataset

    models.fit(x_train, y_train)

    # Prediction the model with test dataset

    y_pred = models.predict(x_test)
    y_pred_prob = models.predict_proba(x_test)

    # Print the model name

    print('Model Name: ', models)

    # confusion matrix in sklearn

    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    # actual values

    actual = y_test

    # predicted values

    predicted = y_pred

    # confusion matrix

    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)

    # outcome values order in sklearn

    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)

    # classification report for precision, recall f1-score and accuracy

    C_Report = classification_report(actual,predicted,labels=[1,0])

    print('Classification report : \n', C_Report)

    # calculating the metrics

    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);

    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);

    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1.
    # A model with a score of +1 is a perfect model and -1 is a poor model

    from math import sqrt

    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)

    # Area under ROC curve

    from sklearn.metrics import roc_curve, roc_auc_score

    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

    # ROC Curve

    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    Model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, models.predict_proba(x_test)[:,1])
    plt.figure()
    #
    plt.plot(fpr, tpr, label= 'Classification Model' % Model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()
    print('-----------------------------------------------------------------------------------------------------')
    #----------------------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'True_Positive': tp,
               'False_Negative': fn,
               'False_Positive': fp,
               'True_Negative': tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    emresults = emresults.append(new_row, ignore_index=True)
# Out:
# Model Name:  LogisticRegression()
# Confusion matrix :
#  [[  293  1105]
#  [  143 10281]]
# Outcome values :
#  293 1105 143 10281
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.67      0.21      0.32      1398
#            0       0.90      0.99      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.79      0.60      0.63     11822
# weighted avg       0.88      0.89      0.87     11822
#
# Accuracy : 89.4 %
# Precision : 67.2 %
# Recall : 21.0 %
# F1 Score : 0.32
# Specificity or True Negative Rate : 98.6 %
# Balanced Accuracy : 59.8 %
# MCC : 0.336
# roc_auc_score: 0.598
# -----------------------------------------------------------------------------------------------------
# Model Name:  DecisionTreeClassifier()
# Confusion matrix :
#  [[ 455  943]
#  [1129 9295]]
# Outcome values :
#  455 943 1129 9295
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.29      0.33      0.31      1398
#            0       0.91      0.89      0.90     10424
#
#     accuracy                           0.82     11822
#    macro avg       0.60      0.61      0.60     11822
# weighted avg       0.83      0.82      0.83     11822
#
# Accuracy : 82.5 %
# Precision : 28.7 %
# Recall : 32.5 %
# F1 Score : 0.305
# Specificity or True Negative Rate : 89.2 %
# Balanced Accuracy : 60.8 %
# MCC : 0.206
# roc_auc_score: 0.609
# -----------------------------------------------------------------------------------------------------
# Model Name:  RandomForestClassifier()
# Confusion matrix :
#  [[  399   999]
#  [  334 10090]]
# Outcome values :
#  399 999 334 10090
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.54      0.29      0.37      1398
#            0       0.91      0.97      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.73      0.63      0.66     11822
# weighted avg       0.87      0.89      0.87     11822
#
# Accuracy : 88.7 %
# Precision : 54.4 %
# Recall : 28.5 %
# F1 Score : 0.374
# Specificity or True Negative Rate : 96.8 %
# Balanced Accuracy : 62.6 %
# MCC : 0.339
# roc_auc_score: 0.627
# -----------------------------------------------------------------------------------------------------
# Model Name:  ExtraTreesClassifier()
# Confusion matrix :
#  [[ 409  989]
#  [ 427 9997]]
# Outcome values :
#  409 989 427 9997
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.49      0.29      0.37      1398
#            0       0.91      0.96      0.93     10424
#
#     accuracy                           0.88     11822
#    macro avg       0.70      0.63      0.65     11822
# weighted avg       0.86      0.88      0.87     11822
#
# Accuracy : 88.0 %
# Precision : 48.9 %
# Recall : 29.3 %
# F1 Score : 0.366
# Specificity or True Negative Rate : 95.9 %
# Balanced Accuracy : 62.6 %
# MCC : 0.317
# roc_auc_score: 0.626
# -----------------------------------------------------------------------------------------------------
# Model Name:  KNeighborsClassifier(n_neighbors=19)
# Confusion matrix :
#  [[  123  1275]
#  [   64 10360]]
# Outcome values :
#  123 1275 64 10360
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.66      0.09      0.16      1398
#            0       0.89      0.99      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.77      0.54      0.55     11822
# weighted avg       0.86      0.89      0.85     11822
#
# Accuracy : 88.7 %
# Precision : 65.8 %
# Recall : 8.8 %
# F1 Score : 0.155
# Specificity or True Negative Rate : 99.4 %
# Balanced Accuracy : 54.1 %
# MCC : 0.212
# roc_auc_score: 0.541
# -----------------------------------------------------------------------------------------------------
# Model Name:  GaussianNB()
# Confusion matrix :
#  [[ 729  669]
#  [1254 9170]]
# Outcome values :
#  729 669 1254 9170
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.37      0.52      0.43      1398
#            0       0.93      0.88      0.91     10424
#
#     accuracy                           0.84     11822
#    macro avg       0.65      0.70      0.67     11822
# weighted avg       0.87      0.84      0.85     11822
#
# Accuracy : 83.7 %
# Precision : 36.8 %
# Recall : 52.1 %
# F1 Score : 0.431
# Specificity or True Negative Rate : 88.0 %
# Balanced Accuracy : 70.0 %
# MCC : 0.347
# roc_auc_score: 0.701
# -----------------------------------------------------------------------------------------------------
# Model Name:  SVC(kernel='poly', probability=True)
# Confusion matrix :
#  [[  230  1168]
#  [  109 10315]]
# Outcome values :
#  230 1168 109 10315
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.68      0.16      0.26      1398
#            0       0.90      0.99      0.94     10424
#
#     accuracy                           0.89     11822
#    macro avg       0.79      0.58      0.60     11822
# weighted avg       0.87      0.89      0.86     11822
#
# Accuracy : 89.2 %
# Precision : 67.8 %
# Recall : 16.5 %
# F1 Score : 0.265
# Specificity or True Negative Rate : 99.0 %
# Balanced Accuracy : 57.8 %
# MCC : 0.298
# roc_auc_score: 0.577
# -----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## comparision results

# %%
emresults
# Out:
#                                           Model Name True_Positive  \
# 0                               LogisticRegression()           293
# 1                           DecisionTreeClassifier()           455
# 2  (DecisionTreeClassifier(max_features='sqrt', r...           399
# 3  (ExtraTreeClassifier(random_state=1368583405),...           409
# 4               KNeighborsClassifier(n_neighbors=19)           123
# 5                                       GaussianNB()           729
# 6               SVC(kernel='poly', probability=True)           230
#
#   False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0           1105            143         10281     0.894      0.672   0.210
# 1            943           1129          9295     0.825      0.287   0.325
# 2            999            334         10090     0.887      0.544   0.285
# 3            989            427          9997     0.880      0.489   0.293
# 4           1275             64         10360     0.887      0.658   0.088
# 5            669           1254          9170     0.837      0.368   0.521
# 6           1168            109         10315     0.892      0.678   0.165
#
#    F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# 0     0.320        0.986  0.336       0.597933              0.598
# 1     0.305        0.892  0.206       0.608579              0.608
# 2     0.374        0.968  0.339       0.626683              0.626
# 3     0.366        0.959  0.317       0.625799              0.626
# 4     0.155        0.994  0.212       0.540922              0.541
# 5     0.431        0.880  0.347       0.700580              0.700
# 6     0.265        0.990  0.298       0.577032              0.578

# %%
y_pred=ModelLR.predict(x_test)

# %%
results=pd.DataFrame({'y_A':y_test,'y_P':y_pred})

# %%
results.head()
# Out:
#        y_A  y_P
# 21561    0    0
# 36430    0    0
# 9008     0    0
# 9736     0    0
# 109      0    0

# %%
resultsf=pdatabk.merge(results,left_index=True,right_index=True)

resultsf.sample(12)
# Out:
#        age            job   marital            education  default  housing  \
# 30671   44       services   married          high.school       no      yes
# 16461   37     unemployed   married  professional.course  unknown      yes
# 25579   46    blue-collar   married             basic.9y       no      yes
# 8445    47  self-employed   married             basic.4y  unknown  unknown
# 13702   23     technician    single  professional.course       no       no
# 12101   49    blue-collar   married             basic.4y       no      yes
# 6604    31       services    single          high.school  unknown      yes
# 38299   36     unemployed   married          high.school       no       no
# 8569    31       services    single          high.school       no      yes
# 10963   28         admin.   married    university.degree       no       no
# 24810   51         admin.   married          high.school       no       no
# 4335    47         admin.  divorced  professional.course  unknown       no
#
#           loan    contact month day_of_week  campaign  pdays  previous  \
# 30671       no   cellular   may         tue         5    999         0
# 16461       no   cellular   jul         wed         1    999         0
# 25579      yes   cellular   nov         wed         1    999         0
# 8445   unknown  telephone   jun         tue         8    999         0
# 13702       no  telephone   jul         thu         1    999         0
# 12101       no  telephone   jun         mon         3    999         0
# 6604        no  telephone   may         wed         1    999         0
# 38299       no  telephone   oct         thu         2    999         0
# 8569        no  telephone   jun         wed         1    999         0
# 10963       no  telephone   jun         wed         1    999         0
# 24810      yes   cellular   nov         tue         1    999         1
# 4335        no  telephone   may         tue         2    999         0
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 30671  nonexistent          -1.8          92.893          -46.2      1.344
# 16461  nonexistent           1.4          93.918          -42.7      4.963
# 25579  nonexistent          -0.1          93.200          -42.0      4.120
# 8445   nonexistent           1.4          94.465          -41.8      4.864
# 13702  nonexistent           1.4          93.918          -42.7      4.963
# 12101  nonexistent           1.4          94.465          -41.8      4.947
# 6604   nonexistent           1.1          93.994          -36.4      4.857
# 38299  nonexistent          -3.4          92.431          -26.9      0.740
# 8569   nonexistent           1.4          94.465          -41.8      4.864
# 10963  nonexistent           1.4          94.465          -41.8      4.962
# 24810      failure          -0.1          93.200          -42.0      4.153
# 4335   nonexistent           1.1          93.994          -36.4      4.856
#
#        nr.employed    y  y_A  y_P
# 30671       5099.1   no    0    0
# 16461       5228.1   no    0    0
# 25579       5195.8  yes    0    0
# 8445        5228.1   no    0    0
# 13702       5228.1   no    0    0
# 12101       5228.1   no    0    0
# 6604        5191.0   no    0    0
# 38299       5017.5   no    1    0
# 8569        5228.1   no    0    0
# 10963       5228.1   no    0    0
# 24810       5195.8   no    0    0
# 4335        5191.0   no    0    0

# %%
resultsf.sample(12)
# Out:
#        age           job   marital            education  default housing loan  \
# 31045   33    technician   married  professional.course       no     yes   no
# 33227   37        admin.   married    university.degree       no     yes  yes
# 3085    45   blue-collar   married             basic.9y  unknown      no   no
# 22492   54   blue-collar   married              unknown  unknown     yes  yes
# 37079   32        admin.    single    university.degree       no     yes   no
# 26404   49    technician   married    university.degree       no     yes   no
# 21453   58       retired   married              unknown  unknown      no  yes
# 5679    52  entrepreneur  divorced          high.school       no      no   no
# 1232    44   blue-collar   married             basic.6y  unknown      no  yes
# 3344    43    technician  divorced  professional.course       no      no   no
# 31387   36   blue-collar   married             basic.9y       no     yes   no
# 38795   49    unemployed   married  professional.course       no     yes  yes
#
#          contact month day_of_week  campaign  pdays  previous     poutcome  \
# 31045   cellular   may         wed         7    999         1      failure
# 33227   cellular   may         tue         1    999         1      failure
# 3085   telephone   may         thu         3    999         0  nonexistent
# 22492   cellular   aug         fri         1    999         0  nonexistent
# 37079  telephone   jul         fri         4    999         0  nonexistent
# 26404   cellular   nov         thu         1    999         0  nonexistent
# 21453   cellular   aug         tue         2    999         0  nonexistent
# 5679   telephone   may         mon         2    999         0  nonexistent
# 1232   telephone   may         thu         1    999         0  nonexistent
# 3344   telephone   may         thu         1    999         0  nonexistent
# 31387   cellular   may         wed         1    999         0  nonexistent
# 38795   cellular   nov         thu         2    999         1      failure
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# 31045          -1.8          92.893          -46.2      1.334       5099.1
# 33227          -1.8          92.893          -46.2      1.291       5099.1
# 3085            1.1          93.994          -36.4      4.860       5191.0
# 22492           1.4          93.444          -36.1      4.964       5228.1
# 37079          -2.9          92.469          -33.6      1.007       5076.2
# 26404          -0.1          93.200          -42.0      4.076       5195.8
# 21453           1.4          93.444          -36.1      4.963       5228.1
# 5679            1.1          93.994          -36.4      4.857       5191.0
# 1232            1.1          93.994          -36.4      4.855       5191.0
# 3344            1.1          93.994          -36.4      4.860       5191.0
# 31387          -1.8          92.893          -46.2      1.334       5099.1
# 38795          -3.4          92.649          -30.1      0.714       5017.5
#
#         y  y_A  y_P
# 31045  no    1    1
# 33227  no    0    0
# 3085   no    0    0
# 22492  no    0    0
# 37079  no    1    1
# 26404  no    1    1
# 21453  no    0    0
# 5679   no    0    0
# 1232   no    0    0
# 3344   no    0    0
# 31387  no    0    0
# 38795  no    0    1

# %% [markdown]
# ##Data Visualisation for actual and predicted values and target varable

# %%
target_counts = pdata['y'].value_counts()

# Get labels and counts for the pie chart
labels = target_counts.index
counts = target_counts.values

# Plot the pie chart
plt.figure(figsize=(8, 8))  # Optional: Set the figure size
plt.pie(counts, labels=labels, autopct='%1.1f%%')
plt.title('Pie Chart of Target Variable')
plt.axis('equal')  # Equal aspect ratio ensures the pie is drawn as a circle.
plt.show()

# %%
target_counts = resultsf['y_A'].value_counts()

# Get labels and counts for the pie chart
labels = target_counts.index
counts = target_counts.values

# Plot the pie chart
plt.figure(figsize=(8, 8))  # Optional: Set the figure size
plt.pie(counts, labels=labels, autopct='%1.1f%%')
plt.title('Pie Chart of Actual values')
plt.axis('equal')  # Equal aspect ratio ensures the pie is drawn as a circle.
plt.show()

# %%
target_counts = resultsf['y_P'].value_counts()

# Get labels and counts for the pie chart
labels = target_counts.index
counts = target_counts.values

# Plot the pie chart
plt.figure(figsize=(8, 8))  # Optional: Set the figure size
plt.pie(counts, labels=labels, autopct='%1.1f%%')
plt.title('Pie Chart of predicted values')
plt.axis('equal')  # Equal aspect ratio ensures the pie is drawn as a circle.
plt.show()

# %%
# Seperate as 2 dataset based on the target variable class
'''
Q1 = psql.sqldf("select * from CCData where Class = 1 ")
Q2 = psql.sqldf("select * from CCData where Class = 0 ")'''

# %%
# Random sample the data as 20% from "Major Class"
'''
Q3 = Q2.groupby('Class', group_keys=False).apply(lambda x: x.sample(frac=0.2))'''
